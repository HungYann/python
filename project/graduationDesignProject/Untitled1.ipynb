# %%
import json
from textwrap import dedent as d

import dash
import dash_core_components as dcc
import dash_html_components as html

from dash.dependencies import Input,Output

external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

app=dash.Dash(__name__,external_stylesheets=external_stylesheets)


styles={
    'pre':{
     'border':'thin lightgrey solid',
     'overflowX':'scroll'
    }
}

app.layout=html.Div([
    dcc.Graph(
    id='basic-interactions',
    figure={
        "data":[
          {
              'x':[1,2,3,4],
              'y':[4,1,3,5],
              'mode':'markers',
              'marker':{'size':12}
          },
          {
              'x':[1,2,3,4],
              'y':[9,4,1,4],
              'mode':'markers',
              'marker':{'size':12}
              
          }  
        ],
        'layout':{
            'clickmode':'event+select'
        }
        
    }
),
    
    html.Div(className='row',children=[
        html.Div([
           dcc.Markdown(
               d("""
               **Selection Data**
               Choose the lasso or rectangle tool in the graph's menu
               bar and then select points in the graph.
               
               Note that if `layout.clickmode='event+selection'`,selection
               data also accumulates(or un-accumaltes)selected data if you
               hold down the shift button while clicking.
               """)), 
               
               html.Pre(id='selected-data',style=styles['pre']),   
        ],className='three columns')  
    ])
])

@app.callback(
    Output('selected-data','children'),
    [Input('basic-interactions','selectedData')])
def display_selected_data(selectedData):
    
    return json.dumps(selectedData,intent=2)

if __name__=='__main__':
    app.run_server(port=4046)
    app.run_server(debug=True,host='0.0.0.0',port=7001)
# Out:
# Running on http://0.0.0.0:7001/
# Running on http://0.0.0.0:7001/
# Running on http://0.0.0.0:7001/
# Running on http://0.0.0.0:7001/
# Running on http://0.0.0.0:7001/
# Running on http://0.0.0.0:7001/
# Debugger PIN: 404-236-003
# Debugger PIN: 404-236-003
# Debugger PIN: 404-236-003
# Debugger PIN: 404-236-003
# Debugger PIN: 404-236-003
# Debugger PIN: 404-236-003
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
form sklearn.metrics import mean_squared_error,r2_score
# Out:
#   File "<ipython-input-5-ff3741464eb1>", line 1
#     form sklearn.metrics import mean_squared_error,r2_score
#                ^
# SyntaxError: invalid syntax

# %%
import plotly
plotly.__version__\
# Out:
# '3.4.2'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace=go.Table(
header=dict(values=['A Scores','B Scores']),
cells=dict(values=[[100,90,80,90],[95,85,75,95]))

data=[trace]
py.iplot(data,filename='basic_table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liuhongyang/29.embed" height="525px" width="100%"></iframe>

# %%
import plotly.plotly as py
import plotly.graph_objs as go

trace=go.Table(
header=dict(values=['A Scores','B Scores'],
           
            align=['left']*5,
           ),
cells=dict(values=[[100,90,80,90],[95,85,75,95]],
         
           align=['left']*5
          ))

layout=dict(width=500,height=300)
data=[trace]
fig=dict(data=data,layout=layout)
py.iplot(fig, filename = 'styled_table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liuhongyang/31.embed" height="300px" width="500px"></iframe>

# %%
from datetime import datetime as dt
import sqlite3
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input,Output
import plotly.graph_objs as go


external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']
app = dash.Dash(__name__, external_stylesheets=external_stylesheets)


df369_0 = pd.read_csv('/Users/liuhongyang/Desktop/369_0.csv')
#df369_1 = pd.read_csv('/Users/liuhongyang/Desktop/369_1.csv')
vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)
mapbox_access_token='pk.eyJ1IjoiaG9ubGl1MTgiLCJhIjoiY2pzN3M4cTBkMDVvNjQ0cXhkcjc4OXM5eiJ9.7a4i9J2IgQ1wC4eh63fcVA'
def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))

app.layout = html.Div([
    html.Div([dcc.Input(id="input")]),

    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2013, 9, 5),
        end_date=dt(2013, 9, 25)
    ),

    html.Div(id='output-container-date-picker-range'),



    html.Div(id='as'),

    html.Div([
        html.Div([
            dcc.Graph(
                id="my"

            )
        ],className="six columns"),

        html.Div([
            dcc.Graph(
                id="map"
            )

        ],className="six columns")

    ],className="row")

])

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import pandas as pd 

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2014_usa_states.csv')

trace=go.Table(
    header=dict(
    values=(df.columns),
    fill=dict(color='#C2D4FF'),
    align=['left']*5
    
    ),
    cells=dict(
    values=(df.Rank,df.State,df.Postal,df.Population),
    fill=dict(color='#F5F8FF'),
    align = ['left'] * 5)
    )
    
data=[trace]
py.iplot(data,filename='pandas_table')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liuhongyang/33.embed" height="525px" width="100%"></iframe>

# %%
#dfsf
#将代码改成csv结构
#重新布局



from datetime import datetime as dt

import sqlite3
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

import plotly.graph_objs as go
import datetime
import plotly.plotly as py


x_axis = []
y_axis = []
vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)
mapbox_access_token='pk.eyJ1IjoiaG9ubGl1MTgiLCJhIjoiY2pzN3M4cTBkMDVvNjQ0cXhkcjc4OXM5eiJ9.7a4i9J2IgQ1wC4eh63fcVA'
def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))


app = dash.Dash(__name__)


app.layout = html.Div([
    html.Div([dcc.Input(id="input")]),

    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2013, 9, 5),
        end_date=dt(2013, 9, 25)
    ),

    html.Div(id='output-container-date-picker-range'),



    html.Div(id='as'),

        dcc.Graph([
                html.Div([
                    dcc.Graph(
                        id='my',
                    )
        ],className="six columns"),

        dcc.Graph([

                html.Div([
                    dcc.Graph(
                        id='map',
                    )
        ],className="six columns"),

    ], className="row")
    ])
])

@app.callback(
    dash.dependencies.Output('as', 'children'),
    [dash.dependencies.Input('my-date-picker-range', 'start_date'),
     dash.dependencies.Input('my-date-picker-range', 'end_date')])
def update_output(start_date, end_date):
    start_date2 = dt(2013, 9, 5)
    end_date2 = dt(2013, 9, 25)

    if start_date is not None:
        start_date2 = dt.strptime(start_date, '%Y-%m-%d')
        print start_date


    if end_date is not None:
        end_date2 = dt.strptime(end_date, '%Y-%m-%d')
        print end_date


    val = end_date2-start_date2
    print(type(val))

    if start_date is not None:
        val2=str(start_date) + " " + str(val)
    else:
        val2=str(start_date2.strftime( '%Y-%m-%d')) + " " + str(val)

    return val2


@app.callback(dash.dependencies.Output('output-container-date-picker-range','children'),
              [dash.dependencies.Input('as','children')])

def chooseData(data):
    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    
    
    result=data.split(" ")
    print result
    print "time"+result[0]
    print "nut number"+result[1]

    #time gap
    thredhold = int(result[1])

    startTime = dt.strptime(result[0],'%Y-%m-%d')

    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days

        if DayValue<0:
            continue;

        if DayValue>=thredhold:
            break;
        #print type((currentDatabaseTimeStamp-startTime).days)
        #print type(num)
        #count=count+1
        #time gap between currentTime and startTime
        x_axis.append(currentDatabaseTimeStamp)
        y_axis.append(row[1])

        #if((val-startTime).days>=0) and ((val-startTime)<num):
          #  x_axis.append(val)
         #   y_axis.append(row[1])
    conn.commit()
    conn.close()
    print x_axis
    print y_axis


@app.callback(
          Output('my','figure'),
          [Input('input','value')])
def create(value):
    data = []
    trace_close = go.Scatter(
        x=x_axis,
        y=y_axis,
        mode='markers'
    )

    data.append(trace_close)

    layout = {"title": "Scatter"}

    return {
        'data': data,
        'layout': layout
    }



@app.callback(
            Output('map','figure'),
            [Input('as','children')])

def mapTrack(maoData):
    time= []
    longgitude = []
    latitude = []

    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result = maoData.split(" ")
    print result
    print "time" + result[0]
    print "nut number" + result[1]

    # time gap
    thredhold = int(result[1])


    startTime = dt.strptime(result[0], '%Y-%m-%d')


    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;

        time.append(currentDatabaseTimeStamp)
        longgitude.append(row[1])
    conn.commit()
    conn.close()

    conn2 = sqlite3.connect('/Users/liuhongyang/Desktop/369_1.db')
    c2 = conn2.cursor()
    cursor2 = c2.execute("SELECT timestamp,value from Data")

    for row in cursor2:

        currentDatabaseTimeStamp = get_datetime(row[0])

        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;

        latitude.append(row[1])
    conn2.commit()
    conn2.close()
    print "---------------->"

    #print longgitude[0]
    #print latitude[0]

    data = [
        go.Scattermapbox(
            lat=longgitude,
            lon=latitude,
            mode='markers',
            marker=dict(
                size=9
            )

        )
    ]

    layout = go.Layout(
        autosize=True,
        hovermode='closest',
        mapbox=dict(
            bearing=0,
            accesstoken=mapbox_access_token,
            center=dict(
                lat=38.92,
                lon=-77.07
            ),
            pitch=0,
            zoom=10
        ),
    )

    return {
        'data': data,
        'layout': layout
    }

if __name__ == '__main__':
    app.run_server(port=4048)

# %%
import plotly.plotly as py
import plotly.graph_objs as go

values = [[['Salaries', 'Office', 'Merchandise', 'Legal', '<b>TOTAL<br>EXPENSES</b>']],
[["Lorem ipsum dolor sit amet, tollit discere inermis pri ut. Eos ea iusto timeam, an prima laboramus vim. Id usu aeterno adversarium, summo mollis timeam vel ad",
  "Lorem ipsum dolor sit amet, tollit discere inermis pri ut. Eos ea iusto timeam, an prima laboramus vim. Id usu aeterno adversarium, summo mollis timeam vel ad",
  "Lorem ipsum dolor sit amet, tollit discere inermis pri ut. Eos ea iusto timeam, an prima laboramus vim. Id usu aeterno adversarium, summo mollis timeam vel ad",
  "Lorem ipsum dolor sit amet, tollit discere inermis pri ut. Eos ea iusto timeam, an prima laboramus vim. Id usu aeterno adversarium, summo mollis timeam vel ad",
  "Lorem ipsum dolor sit amet, tollit discere inermis pri ut. Eos ea iusto timeam, an prima laboramus vim. Id usu aeterno adversarium, summo mollis timeam vel ad"]]]

trace0=go.Table(
columnorder=[1,2],
columnwidth=[80,400],
header=dict(
values = [['<b>EXPENSES</b><br>as of July 2017'],
                  ['<b>DESCRIPTION</b>']],
    line = dict(color = '#506784'),
    fill = dict(color = '#119DFF'),
    align = ['left','center'],
    font = dict(color = 'white', size = 12),
    height = 40
),
cells=dict(
values=values,
line = dict(color = '#506784'),
fill = dict(color = ['#25FEFD', 'white']),
align = ['left', 'center'],
font = dict(color = '#506784', size = 12),
height = 30  
)
)









data=[trace0]

py.iplot(data, filename = "Row and Column Size")
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~liuhongyang/35.embed" height="525px" width="100%"></iframe>

# %%
from datetime import datetime as dt
from datetime import timedelta
import dash_html_components as html
import dash_core_components as dcc
import sqlite3
import dash
from dash.dependencies import Input, Output
import datetime
import folium
import datetime



time0=[]
longgitude=[]
time1=[]
latitude=[]

def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))

vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)


conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
c = conn.cursor()
cursor = c.execute("SELECT timestamp,value from Data")

count=0
for row in cursor:
    currentDatabaseTimeStamp = get_datetime(row[0])
    time0.append(currentDatabaseTimeStamp)
    longgitude.append(row[1])
    count=count+1
    if count>3000:
        break

  
conn2 = sqlite3.connect('/Users/liuhongyang/Desktop/369_1.db') 
c2 = conn2.cursor()
cursor2 = c2.execute("SELECT timestamp,value from Data")
for row in cursor2:
    currentDatabaseTimeStamp = get_datetime(row[0])
    time1.append(currentDatabaseTimeStamp)
    latitude.append(row[1])
    
        
conn.commit()
conn.close()
conn2.commit()
conn2.close()


m = folium.Map(location=[58.488869,16.571034],
              zoom_start=20,
              control_scale=True)

'''为m添加标记部件'''

num = len(longgitude)
print num
for i in range(0,num):
    folium.Circle(
        radius=1,
        location=[58+longgitude[i],16+latitude[i]],
        color='crimson',
        fill=False,
    ).add_to(m)
 

m
# Out:
# 3001
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#1810
from datetime import datetime as dt
from datetime import timedelta
import dash
import dash_html_components as html
import dash_core_components as dcc
import sqlite3
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import json
import plotly.graph_objs as go
import datetime
import plotly.plotly as py


x_axis = []
y_axis = []
longgitude = []
latitude = []

vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)

def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))


app = dash.Dash(__name__)
app.layout = html.Div([
    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2013, 9, 5),
        end_date=dt(2013, 9, 25)
    ),
    html.Div(id='output-container-date-picker-range'),

    html.Div(id='as'),
    html.Div([dcc.Input(id="input")]),

    html.Div([dcc.Graph(id='my')]),


    html.Div([dcc.Graph(id='map-graph')])


])


@app.callback(
    dash.dependencies.Output('as', 'children'),
    [dash.dependencies.Input('my-date-picker-range', 'start_date'),
     dash.dependencies.Input('my-date-picker-range', 'end_date')])
def update_output(start_date, end_date):
    start_date2 = dt(2013, 9, 5)
    end_date2 = dt(2013, 9, 25)

    if start_date is not None:
        start_date2 = dt.strptime(start_date, '%Y-%m-%d')
        print start_date


    if end_date is not None:
        end_date2 = dt.strptime(end_date, '%Y-%m-%d')
        print end_date


    val = end_date2-start_date2
    print(type(val))

    if start_date is not None:
        val2=str(start_date) + " " + str(val)
    else:
        val2=str(start_date2.strftime( '%Y-%m-%d')) + " " + str(val)

    return val2


@app.callback(dash.dependencies.Output('output-container-date-picker-range','children'),
              [dash.dependencies.Input('as','children')])

def chooseData(data):
    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result=data.split(" ")
    print result
    print "time"+result[0]
    print "nut number"+result[1]

    #time gap
    thredhold = int(result[1])

    startTime = dt.strptime(result[0],'%Y-%m-%d')

    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days

        if DayValue<0:
            continue;

        if DayValue>=thredhold:
            break;
        #print type((currentDatabaseTimeStamp-startTime).days)
        #print type(num)
        #count=count+1
        #time gap between currentTime and startTime
        x_axis.append(currentDatabaseTimeStamp)
        y_axis.append(row[1])

        #if((val-startTime).days>=0) and ((val-startTime)<num):
          #  x_axis.append(val)
         #   y_axis.append(row[1])
    conn.commit()
    conn.close()
    print x_axis
    print y_axis


@app.callback(
          Output('my','figure'),
          [Input('input','value')])
def create(value):
    data = []
    trace_close = go.Scatter(
        x=x_axis,
        y=y_axis,
        mode='markers'
    )

    data.append(trace_close)

    layout = {"title": "Scatter"}

    return {
        'data': data,
        'layout': layout
    }



@app.callback(
            Output('map-graph','figure'),
            [Input('as','children')])

def mapTrack(maoData):
    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result = maoData.split(" ")
    print result
    print "time" + result[0]
    print "nut number" + result[1]

    # time gap
    thredhold = int(result[1])


    startTime = dt.strptime(result[0], '%Y-%m-%d')


    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;
        longgitude.append(row[1])



    conn2 = sqlite3.connect('/Users/liuhongyang/Desktop/369_1.db')
    c2 = conn2.cursor()
    cursor2 = c2.execute("SELECT timestamp,value from Data")

    for row in cursor2:

        currentDatabaseTimeStamp = get_datetime(row[0])

        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;

        latitude.append(row[1])

    conn.commit()
    conn.close()
    conn2.commit()
    conn2.close()
    print "<---------------->"

    #print longgitude[0]
    #print latitude[0]

    return {
        "data":[{
                "lat":longgitude,
                "lon":latitude,
                "mode":'markers',
                "marker":{
                     "size" : 9
                }
        }],

        "layout": dict(
            autosize=True,
            hovermode='closest',
            mapbox=dict(
                bearing=0,
                center=dict(
                    lat=38.92,
                    lon=-77.07
                ),
                pitch=0,
                zoom=10
            ),
        )

    }



if __name__ == '__main__':
    app.run_server(port=4046)

# %%
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `folium'
# /bin/sh: -c: line 0: `man(folium)'

# %%
from datetime import datetime as dt
from datetime import timedelta
import dash
import dash_html_components as html
import dash_core_components as dcc
import sqlite3
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import json
import plotly.graph_objs as go
import datetime


x_axis = []
y_axis = []
vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)

def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))


app = dash.Dash(__name__)
app.layout = html.Div([
    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2013, 9, 5),
        end_date=dt(2013, 9, 25)
    ),
    html.Div(id='output-container-date-picker-range'),

    html.Div(id='as'),
    html.Div([dcc.Input(id="input")]),

    html.Div([dcc.Graph(id='my')])

])


@app.callback(
    dash.dependencies.Output('as', 'children'),
    [dash.dependencies.Input('my-date-picker-range', 'start_date'),
     dash.dependencies.Input('my-date-picker-range', 'end_date')])
def update_output(start_date, end_date):
    start_date2 = dt(2013, 9, 5)
    end_date2 = dt(2013, 9, 25)

    if start_date is not None:
        start_date2 = dt.strptime(start_date, '%Y-%m-%d')
        print start_date


    if end_date is not None:
        end_date2 = dt.strptime(end_date, '%Y-%m-%d')
        print end_date


    val = end_date2-start_date2
    print(type(val))

    if start_date is not None:
        val2=str(start_date) + " " + str(val)
    else:
        val2=str(start_date2.strftime( '%Y-%m-%d')) + " " + str(val)

    return val2


@app.callback(dash.dependencies.Output('output-container-date-picker-range','children'),
              [dash.dependencies.Input('as','children')])

def chooseData(data):
    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result=data.split(" ")
    print result
    print "time"+result[0]
    print "nut number"+result[1]

    #time gap
    thredhold = int(result[1])

    startTime = dt.strptime(result[0],'%Y-%m-%d')

    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days

        if DayValue<0:
            continue;



        if DayValue>=thredhold:
            break;
        #print type((currentDatabaseTimeStamp-startTime).days)
        #print type(num)
        #count=count+1
        #time gap between currentTime and startTime
        x_axis.append(currentDatabaseTimeStamp)
        y_axis.append(row[1])

        #if((val-startTime).days>=0) and ((val-startTime)<num):
          #  x_axis.append(val)
         #   y_axis.append(row[1])
    conn.commit()
    conn.close()
    print x_axis
    print y_axis

@app.callback(
          Output('my','figure'),
          [Input('input','value')])
def create(value):
    data = []
    trace_close = go.Scatter(
        x=x_axis,
        y=y_axis,
        mode='markers'
    )

    data.append(trace_close)

    layout = {"title": "Scatter"}

    return {
        'data': data,
        'layout': layout
    }



if __name__ == '__main__':
    app.run_server(port=4047)
# Out:
# 2013-09-25
# <type 'datetime.timedelta'>
# Opened A_16929.db successfully
# Operation A_16929.db successfully
# [u'2013-09-05', u'20', u'days,', u'0:00:00']
# time2013-09-05
# nut number20
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# 2013-09-17
# 2013-09-25
# <type 'datetime.timedelta'>
# Opened A_16929.db successfully
# Operation A_16929.db successfully
# [u'2013-09-17', u'8', u'days,', u'0:00:00']
# time2013-09-17
# nut number8
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# 2013-09-17
# 2013-09-18
# <type 'datetime.timedelta'>
# Opened A_16929.db successfully
# Operation A_16929.db successfully
# ...

# %%
from datetime import datetime as dt
from datetime import timedelta
import dash
import dash_html_components as html
import dash_core_components as dcc
import sqlite3
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import json
import plotly.graph_objs as go
import datetime
import plotly.plotly as py


x_axis = []
y_axis = []
vact_epoch = datetime.datetime(year=2011, month=6, day=16, hour=5, minute=23, second=0)

def get_datetime(_value):
    return vact_epoch + datetime.timedelta(milliseconds=int(_value))


app = dash.Dash(__name__)
app.layout = html.Div([
    dcc.DatePickerRange(
        id='my-date-picker-range',
        min_date_allowed=dt(1995, 8, 5),
        max_date_allowed=dt(2017, 9, 19),
        initial_visible_month=dt(2013, 9, 5),
        end_date=dt(2013, 9, 25)
    ),
    html.Div(id='output-container-date-picker-range'),

    html.Div(id='as'),
    html.Div([dcc.Input(id="input")]),

    html.Div([dcc.Graph(id='my')]),

    html.Div(dcc.Graph(id='map'))

])


@app.callback(
    dash.dependencies.Output('as', 'children'),
    [dash.dependencies.Input('my-date-picker-range', 'start_date'),
     dash.dependencies.Input('my-date-picker-range', 'end_date')])
def update_output(start_date, end_date):
    start_date2 = dt(2013, 9, 5)
    end_date2 = dt(2013, 9, 25)

    if start_date is not None:
        start_date2 = dt.strptime(start_date, '%Y-%m-%d')
        print start_date


    if end_date is not None:
        end_date2 = dt.strptime(end_date, '%Y-%m-%d')
        print end_date


    val = end_date2-start_date2
    print(type(val))

    if start_date is not None:
        val2=str(start_date) + " " + str(val)
    else:
        val2=str(start_date2.strftime( '%Y-%m-%d')) + " " + str(val)

    return val2


@app.callback(dash.dependencies.Output('output-container-date-picker-range','children'),
              [dash.dependencies.Input('as','children'))

def chooseData(data):
    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result=data.split(" ")
    print result
    print "time"+result[0]
    print "nut number"+result[1]

    #time gap
    thredhold = int(result[1])

    startTime = dt.strptime(result[0],'%Y-%m-%d')

    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days

        if DayValue<0:
            continue;

        if DayValue>=thredhold:
            break;
        #print type((currentDatabaseTimeStamp-startTime).days)
        #print type(num)
        #count=count+1
        #time gap between currentTime and startTime
        x_axis.append(currentDatabaseTimeStamp)
        y_axis.append(row[1])

        #if((val-startTime).days>=0) and ((val-startTime)<num):
          #  x_axis.append(val)
         #   y_axis.append(row[1])
    conn.commit()
    conn.close()
    print x_axis
    print y_axis


@app.callback(
          Output('my','figure'),
          [Input('input','value')])
def create(value):
    data = []
    trace_close = go.Scatter(
        x=x_axis,
        y=y_axis,
        mode='markers'
    )

    data.append(trace_close)

    layout = {"title": "Scatter"}

    return {
        'data': data,
        'layout': layout
    }



@app.callback(
            Output('map','figure'),
            [Input('as','children')])

def mapTrack(maoData):
    time= []
    longgitude = []
    latitude = []

    conn = sqlite3.connect('/Users/liuhongyang/Desktop/369_0.db')
    c = conn.cursor()
    print "Opened A_16929.db successfully";
    cursor = c.execute("SELECT timestamp,value from Data")

    print "Operation A_16929.db successfully";
    result = maoData.split(" ")
    print result
    print "time" + result[0]
    print "nut number" + result[1]

    # time gap
    thredhold = int(result[1])


    startTime = dt.strptime(result[0], '%Y-%m-%d')


    for row in cursor:
        currentDatabaseTimeStamp = get_datetime(row[0])
        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;

        time.append(currentDatabaseTimeStamp)
        longgitude.append(row[1])
    conn.commit()
    conn.close()

    conn2 = sqlite3.connect('/Users/liuhongyang/Desktop/369_1.db')
    c2 = conn2.cursor()
    cursor2 = c2.execute("SELECT timestamp,value from Data")

    for row in cursor2:

        currentDatabaseTimeStamp = get_datetime(row[0])

        DayValue = (currentDatabaseTimeStamp - startTime).days
        if DayValue < 0:
            continue;

        if DayValue >= thredhold:
            break;

        latitude.append(row[1])
    conn2.commit()
    conn2.close()
    print "---------------->"

    #print longgitude[0]
    #print latitude[0]

    data = [
        go.Scattermapbox(
            lat=longgitude,
            lon=latitude,
            mode='markers',
            marker=dict(
                size=9
            )

        )
    ]

    layout = go.Layout(
        autosize=True,
        hovermode='closest',
        mapbox=dict(
            bearing=0,
            center=dict(
                lat=38.92,
                lon=-77.07
            ),
            pitch=0,
            zoom=10
        ),
    )

    return {
        'data': data,
        'layout': layout
    }

if __name__ == '__main__':
    app.run_server(port=4047)
